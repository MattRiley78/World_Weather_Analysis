# %%
#Import Dependencies and Keys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
longs = np.random.uniform(low=-90, high=90, size=2000)
latlongs = zip(lats, longs)
latlongs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(latlongs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 791

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data= []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.  Sleep for 60 seconds.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gondar
# Processing Record 2 of Set 1 | fereydun kenar
# Processing Record 3 of Set 1 | olafsvik
# Processing Record 4 of Set 1 | sinnamary
# Processing Record 5 of Set 1 | cururupu
# Processing Record 6 of Set 1 | eyl
# Processing Record 7 of Set 1 | sankeshwar
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | banepa
# Processing Record 10 of Set 1 | saint anthony
# Processing Record 11 of Set 1 | grand-santi
# Processing Record 12 of Set 1 | sistranda
# Processing Record 13 of Set 1 | ciudad bolivar
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | albion
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | phalodi
# Processing Record 20 of Set 1 | anajatuba
# Processing Record 21 of Set 1 | husavik
# Processing Record 22 of Set 1 | new baltimore
# Processing Record 23 of Set 1 | kangasala
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | chernaya kholunitsa
# Processing Record 26 of Set 1 | san andres
# Processing Record 27 of Set 1 | jacareacanga
# Processing Record 28 of Set 1 | nortelandia
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | emba
# Processing Record 31 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | vilhena
# Processing Record 34 of Set 1 | augusta
# Processing Record 35 of Set 1 | altay
# Processing Record 36 of Set 1 | mwinilunga
# Processing Record 37 of Set 1 | grindavik
# Processing Record 38 of Set 1 | silvassa
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | ballina
# Processing Record 41 of Set 1 | pietarsaari
# Processing Record 42 of Set 1 | la baule-escoublac
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | sandviken
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | ormara
# Processing Record 47 of Set 1 | itarema
# Processing Record 48 of Set 1 | berlevag
# Processing Record 49 of Set 1 | aguimes
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | blagodatnoye
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | siena
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | karatau
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | sao jose do calcado
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 2 | rincon
# Processing Record 15 of Set 2 | havre-saint-pierre
# Processing Record 16 of Set 2 | kavaratti
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | jega
# Processing Record 20 of Set 2 | bara
# Processing Record 21 of Set 2 | freetown
# Processing Record 22 of Set 2 | maniitsoq
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | puri
# Processing Record 27 of Set 2 | tokonou
# Processing Record 28 of Set 2 | salisbury
# Processing Record 29 of Set 2 | iracoubo
# Processing Record 30 of Set 2 | rio gallegos
# Processing Record 31 of Set 2 | ardrishaig
# Processing Record 32 of Set 2 | yarada
# Processing Record 33 of Set 2 | puerto ayacucho
# Processing Record 34 of Set 2 | les cayes
# Processing Record 35 of Set 2 | coro
# Processing Record 36 of Set 2 | annau
# Processing Record 37 of Set 2 | muromtsevo
# Processing Record 38 of Set 2 | cockburn town
# Processing Record 39 of Set 2 | dobele
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | mattru
# Processing Record 44 of Set 2 | vila velha
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | mouzakion
# City not found. Skipping...
# Processing Record 47 of Set 2 | clarksburg
# Processing Record 48 of Set 2 | presidencia roque saenz pena
# Processing Record 49 of Set 2 | sao jose de piranhas
# Processing Record 50 of Set 2 | agdas
# Processing Record 1 of Set 3 | sept-iles
# Processing Record 2 of Set 3 | igrim
# Processing Record 3 of Set 3 | parana
# Processing Record 4 of Set 3 | shahjahanpur
# Processing Record 5 of Set 3 | sindand
# City not found. Skipping...
# Processing Record 6 of Set 3 | kabwe
# Processing Record 7 of Set 3 | mutoko
# Processing Record 8 of Set 3 | pangnirtung
# Processing Record 9 of Set 3 | rabat
# Processing Record 10 of Set 3 | severnyy
# Processing Record 11 of Set 3 | codrington
# Processing Record 12 of Set 3 | den helder
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | the valley
# Processing Record 15 of Set 3 | vangaindrano
# Processing Record 16 of Set 3 | juodupe
# Processing Record 17 of Set 3 | sabya
# Processing Record 18 of Set 3 | miranda do corvo
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | tazovskiy
# Processing Record 21 of Set 3 | plettenberg bay
# Processing Record 22 of Set 3 | adamovka
# Processing Record 23 of Set 3 | takoradi
# Processing Record 24 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 3 | riyadh
# Processing Record 26 of Set 3 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 3 | keti bandar
# Processing Record 28 of Set 3 | astana
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | binga
# Processing Record 31 of Set 3 | pinega
# Processing Record 32 of Set 3 | port shepstone
# Processing Record 33 of Set 3 | meiganga
# Processing Record 34 of Set 3 | sochi
# Processing Record 35 of Set 3 | ambilobe
# Processing Record 36 of Set 3 | samoded
# Processing Record 37 of Set 3 | caravelas
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | orai
# Processing Record 42 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 3 | esil
# Processing Record 44 of Set 3 | margate
# Processing Record 45 of Set 3 | luanda
# Processing Record 46 of Set 3 | molina
# Processing Record 47 of Set 3 | saint-raphael
# Processing Record 48 of Set 3 | bubaque
# Processing Record 49 of Set 3 | shamgarh
# Processing Record 50 of Set 3 | abalak
# Processing Record 1 of Set 4 | aketi
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | nalut
# Processing Record 4 of Set 4 | ushtobe
# Processing Record 5 of Set 4 | mitsamiouli
# Processing Record 6 of Set 4 | abu kamal
# Processing Record 7 of Set 4 | sebnitz
# Processing Record 8 of Set 4 | camana
# Processing Record 9 of Set 4 | garissa
# Processing Record 10 of Set 4 | onega
# Processing Record 11 of Set 4 | bangassou
# Processing Record 12 of Set 4 | blaubeuren
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | locri
# Processing Record 17 of Set 4 | verdalsora
# City not found. Skipping...
# Processing Record 18 of Set 4 | oyem
# Processing Record 19 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 21 of Set 4 | saint-louis
# Processing Record 22 of Set 4 | qasigiannguit
# Processing Record 23 of Set 4 | bowling green
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | vaijapur
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | monrovia
# Processing Record 29 of Set 4 | san-pedro
# Processing Record 30 of Set 4 | campbellsville
# Processing Record 31 of Set 4 | hualmay
# Processing Record 32 of Set 4 | carnot
# Processing Record 33 of Set 4 | dobsice
# Processing Record 34 of Set 4 | salym
# Processing Record 35 of Set 4 | dibaya
# City not found. Skipping...
# Processing Record 36 of Set 4 | walvis bay
# Processing Record 37 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 4 | bilma
# Processing Record 39 of Set 4 | sehithwa
# Processing Record 40 of Set 4 | arlit
# Processing Record 41 of Set 4 | cap-aux-meules
# Processing Record 42 of Set 4 | mayahi
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | batticaloa
# Processing Record 45 of Set 4 | pryazha
# Processing Record 46 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 4 | porto santo
# Processing Record 48 of Set 4 | sisimiut
# Processing Record 49 of Set 4 | axim
# Processing Record 50 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 5 | sosua
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | almansa
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | liverpool
# Processing Record 6 of Set 5 | la romana
# Processing Record 7 of Set 5 | nagaur
# Processing Record 8 of Set 5 | skhisma
# Processing Record 9 of Set 5 | roura
# Processing Record 10 of Set 5 | taywarah
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | coari
# Processing Record 13 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 5 | coquimbo
# Processing Record 15 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 5 | najran
# Processing Record 17 of Set 5 | llallagua
# Processing Record 18 of Set 5 | libreville
# Processing Record 19 of Set 5 | sao jose da coroa grande
# Processing Record 20 of Set 5 | duki
# Processing Record 21 of Set 5 | birjand
# Processing Record 22 of Set 5 | grand falls
# Processing Record 23 of Set 5 | longyearbyen
# Processing Record 24 of Set 5 | taltal
# Processing Record 25 of Set 5 | sur
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | skjervoy
# Processing Record 28 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | sechura
# Processing Record 30 of Set 5 | waddan
# Processing Record 31 of Set 5 | ilulissat
# Processing Record 32 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 5 | kargasok
# Processing Record 35 of Set 5 | atkinson
# Processing Record 36 of Set 5 | bud
# Processing Record 37 of Set 5 | novobelokatay
# Processing Record 38 of Set 5 | kapiri mposhi
# Processing Record 39 of Set 5 | iskateley
# Processing Record 40 of Set 5 | goderich
# Processing Record 41 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | vestmanna
# Processing Record 44 of Set 5 | tiruvottiyur
# City not found. Skipping...
# Processing Record 45 of Set 5 | qunduz
# Processing Record 46 of Set 5 | nouadhibou
# Processing Record 47 of Set 5 | yarmouth
# Processing Record 48 of Set 5 | gainsborough
# Processing Record 49 of Set 5 | maine-soroa
# Processing Record 50 of Set 5 | komsomolskiy
# Processing Record 1 of Set 6 | leshukonskoye
# Processing Record 2 of Set 6 | marsh harbour
# Processing Record 3 of Set 6 | marfino
# Processing Record 4 of Set 6 | zile
# Processing Record 5 of Set 6 | qaqortoq
# Processing Record 6 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | la primavera
# Processing Record 9 of Set 6 | thompson
# Processing Record 10 of Set 6 | dwarka
# Processing Record 11 of Set 6 | santa cruz
# Processing Record 12 of Set 6 | kinkala
# Processing Record 13 of Set 6 | necochea
# Processing Record 14 of Set 6 | carballo
# Processing Record 15 of Set 6 | zheleznodorozhnyy
# Processing Record 16 of Set 6 | thunder bay
# Processing Record 17 of Set 6 | san giovanni in fiore
# Processing Record 18 of Set 6 | imbituba
# Processing Record 19 of Set 6 | havelock
# Processing Record 20 of Set 6 | constantine
# Processing Record 21 of Set 6 | thinadhoo
# Processing Record 22 of Set 6 | cayenne
# Processing Record 23 of Set 6 | narayanpet
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | camamu
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | dosso
# Processing Record 28 of Set 6 | guanica
# Processing Record 29 of Set 6 | tallahassee
# Processing Record 30 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 6 | antofagasta
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | zenzeli
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | matara
# Processing Record 36 of Set 6 | beloha
# Processing Record 37 of Set 6 | los llanos de aridane
# Processing Record 38 of Set 6 | belyy yar
# Processing Record 39 of Set 6 | mangan
# Processing Record 40 of Set 6 | baghdad
# Processing Record 41 of Set 6 | wattegama
# Processing Record 42 of Set 6 | marzuq
# Processing Record 43 of Set 6 | gamba
# Processing Record 44 of Set 6 | clyde river
# Processing Record 45 of Set 6 | zyryanovsk
# Processing Record 46 of Set 6 | rio de janeiro
# Processing Record 47 of Set 6 | disna
# Processing Record 48 of Set 6 | rio grande
# Processing Record 49 of Set 6 | sarahan
# Processing Record 50 of Set 6 | kedrovyy
# Processing Record 1 of Set 7 | cap malheureux
# Processing Record 2 of Set 7 | anastacio
# Processing Record 3 of Set 7 | chapais
# Processing Record 4 of Set 7 | mizdah
# Processing Record 5 of Set 7 | manaus
# Processing Record 6 of Set 7 | yar-sale
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | guaranda
# Processing Record 9 of Set 7 | hamilton
# Processing Record 10 of Set 7 | dingle
# Processing Record 11 of Set 7 | ullapool
# Processing Record 12 of Set 7 | hambantota
# Processing Record 13 of Set 7 | buritizeiro
# Processing Record 14 of Set 7 | la arena
# Processing Record 15 of Set 7 | fevik
# Processing Record 16 of Set 7 | turukhansk
# Processing Record 17 of Set 7 | mahebourg
# Processing Record 18 of Set 7 | nioki
# Processing Record 19 of Set 7 | saint-augustin
# Processing Record 20 of Set 7 | oktyabrskiy
# Processing Record 21 of Set 7 | ulsteinvik
# Processing Record 22 of Set 7 | crisan
# Processing Record 23 of Set 7 | lixourion
# Processing Record 24 of Set 7 | benoy
# Processing Record 25 of Set 7 | krasnaya gora
# Processing Record 26 of Set 7 | pokhara
# Processing Record 27 of Set 7 | adrar
# Processing Record 28 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 7 | grand gaube
# Processing Record 30 of Set 7 | pasni
# Processing Record 31 of Set 7 | tupelo
# Processing Record 32 of Set 7 | muisne
# Processing Record 33 of Set 7 | paamiut
# Processing Record 34 of Set 7 | lannion
# Processing Record 35 of Set 7 | duku
# Processing Record 36 of Set 7 | mbour
# Processing Record 37 of Set 7 | aksu
# Processing Record 38 of Set 7 | strezhevoy
# Processing Record 39 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | zugdidi
# Processing Record 41 of Set 7 | bandarbeyla
# Processing Record 42 of Set 7 | conde
# Processing Record 43 of Set 7 | touros
# Processing Record 44 of Set 7 | buenos aires
# Processing Record 45 of Set 7 | kosh-agach
# Processing Record 46 of Set 7 | jha jha
# Processing Record 47 of Set 7 | taoudenni
# Processing Record 48 of Set 7 | islampur
# Processing Record 49 of Set 7 | beyneu
# Processing Record 50 of Set 7 | george town
# Processing Record 1 of Set 8 | omboue
# Processing Record 2 of Set 8 | devgarh
# Processing Record 3 of Set 8 | boz
# Processing Record 4 of Set 8 | waldshut-tiengen
# Processing Record 5 of Set 8 | tir pol
# City not found. Skipping...
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 8 | sao francisco de assis
# Processing Record 9 of Set 8 | podosinovets
# Processing Record 10 of Set 8 | tucuman
# Processing Record 11 of Set 8 | santa rita
# Processing Record 12 of Set 8 | karaikkudi
# Processing Record 13 of Set 8 | ouallam
# Processing Record 14 of Set 8 | kibara
# Processing Record 15 of Set 8 | yabelo
# Processing Record 16 of Set 8 | bonthe
# Processing Record 17 of Set 8 | saint-georges
# Processing Record 18 of Set 8 | general pico
# Processing Record 19 of Set 8 | lar
# Processing Record 20 of Set 8 | kishi
# Processing Record 21 of Set 8 | halifax
# Processing Record 22 of Set 8 | maragogi
# Processing Record 23 of Set 8 | borovoy
# Processing Record 24 of Set 8 | novobirilyussy
# Processing Record 25 of Set 8 | atakpame
# Processing Record 26 of Set 8 | tsaratanana
# Processing Record 27 of Set 8 | la palma
# Processing Record 28 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 29 of Set 8 | morropon
# Processing Record 30 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 8 | high rock
# Processing Record 32 of Set 8 | marawi
# Processing Record 33 of Set 8 | forbesganj
# Processing Record 34 of Set 8 | nioro
# Processing Record 35 of Set 8 | barra
# Processing Record 36 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 37 of Set 8 | vardo
# Processing Record 38 of Set 8 | honningsvag
# Processing Record 39 of Set 8 | kashan
# Processing Record 40 of Set 8 | jalalabad
# Processing Record 41 of Set 8 | gat
# Processing Record 42 of Set 8 | kidal
# Processing Record 43 of Set 8 | sladkovo
# Processing Record 44 of Set 8 | awbari
# Processing Record 45 of Set 8 | gwadar
# Processing Record 46 of Set 8 | pozo colorado
# Processing Record 47 of Set 8 | saint-joseph
# Processing Record 48 of Set 8 | tartagal
# Processing Record 49 of Set 8 | puerto carreno
# Processing Record 50 of Set 8 | moroni
# Processing Record 1 of Set 9 | tsabong
# Processing Record 2 of Set 9 | lebu
# Processing Record 3 of Set 9 | lagos
# Processing Record 4 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 5 of Set 9 | ouadda
# Processing Record 6 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | masunga
# Processing Record 8 of Set 9 | aksarka
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | umm lajj
# Processing Record 11 of Set 9 | natal
# Processing Record 12 of Set 9 | issia
# Processing Record 13 of Set 9 | narsaq
# Processing Record 14 of Set 9 | chimoio
# Processing Record 15 of Set 9 | nosy varika
# Processing Record 16 of Set 9 | chalmette
# Processing Record 17 of Set 9 | waspan
# Processing Record 18 of Set 9 | tromso
# Processing Record 19 of Set 9 | balkany
# Processing Record 20 of Set 9 | bathsheba
# Processing Record 21 of Set 9 | buraydah
# Processing Record 22 of Set 9 | krasnik
# Processing Record 23 of Set 9 | pauini
# Processing Record 24 of Set 9 | zhanaozen
# Processing Record 25 of Set 9 | jodhpur
# Processing Record 26 of Set 9 | ayakudi
# Processing Record 27 of Set 9 | nakambala
# Processing Record 28 of Set 9 | mbandaka
# Processing Record 29 of Set 9 | sotouboua
# Processing Record 30 of Set 9 | kristiansund
# Processing Record 31 of Set 9 | zorgo
# Processing Record 32 of Set 9 | raudeberg
# Processing Record 33 of Set 9 | awka
# Processing Record 34 of Set 9 | la rioja
# Processing Record 35 of Set 9 | ratnagiri
# Processing Record 36 of Set 9 | el alto
# Processing Record 37 of Set 9 | rawson
# Processing Record 38 of Set 9 | mogadishu
# Processing Record 39 of Set 9 | mao
# Processing Record 40 of Set 9 | fuengirola
# Processing Record 41 of Set 9 | atar
# Processing Record 42 of Set 9 | fez
# Processing Record 43 of Set 9 | gaya
# Processing Record 44 of Set 9 | qobustan
# Processing Record 45 of Set 9 | baltasi
# Processing Record 46 of Set 9 | narsipatnam
# Processing Record 47 of Set 9 | surt
# Processing Record 48 of Set 9 | new bern
# Processing Record 49 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 9 | menongue
# Processing Record 1 of Set 10 | malkara
# Processing Record 2 of Set 10 | puerto leguizamo
# Processing Record 3 of Set 10 | boa vista
# Processing Record 4 of Set 10 | la colmena
# Processing Record 5 of Set 10 | bani
# Processing Record 6 of Set 10 | bahia honda
# Processing Record 7 of Set 10 | salinopolis
# Processing Record 8 of Set 10 | guarapari
# Processing Record 9 of Set 10 | barranca
# Processing Record 10 of Set 10 | naples
# Processing Record 11 of Set 10 | lahij
# Processing Record 12 of Set 10 | mayor pablo lagerenza
# Processing Record 13 of Set 10 | esmeraldas
# Processing Record 14 of Set 10 | luderitz
# Processing Record 15 of Set 10 | san cristobal
# Processing Record 16 of Set 10 | abha
# Processing Record 17 of Set 10 | begunitsy
# Processing Record 18 of Set 10 | zambezi
# Processing Record 19 of Set 10 | gunjur
# Processing Record 20 of Set 10 | comodoro rivadavia
# Processing Record 21 of Set 10 | sann
# Processing Record 22 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 23 of Set 10 | botshabelo
# Processing Record 24 of Set 10 | vuktyl
# Processing Record 25 of Set 10 | werda
# Processing Record 26 of Set 10 | praia da vitoria
# Processing Record 27 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 28 of Set 10 | santiago del estero
# Processing Record 29 of Set 10 | muncie
# Processing Record 30 of Set 10 | tibati
# Processing Record 31 of Set 10 | aripuana
# Processing Record 32 of Set 10 | rogovatoye
# Processing Record 33 of Set 10 | boende
# Processing Record 34 of Set 10 | hobyo
# Processing Record 35 of Set 10 | gidam
# Processing Record 36 of Set 10 | quatre cocos
# Processing Record 37 of Set 10 | panaba
# Processing Record 38 of Set 10 | port maria
# Processing Record 39 of Set 10 | bogatyye saby
# Processing Record 40 of Set 10 | roald
# Processing Record 41 of Set 10 | mezen
# Processing Record 42 of Set 10 | nantucket
# Processing Record 43 of Set 10 | koubia
# Processing Record 44 of Set 10 | magole
# Processing Record 45 of Set 10 | ghanzi
# Processing Record 46 of Set 10 | misratah
# Processing Record 47 of Set 10 | umuarama
# Processing Record 48 of Set 10 | marrakesh
# Processing Record 49 of Set 10 | hofn
# Processing Record 50 of Set 10 | marsabit
# Processing Record 1 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 11 | cabedelo
# Processing Record 3 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 11 | itaituba
# Processing Record 5 of Set 11 | nurlat
# Processing Record 6 of Set 11 | port hawkesbury
# Processing Record 7 of Set 11 | winneba
# Processing Record 8 of Set 11 | talnakh
# Processing Record 9 of Set 11 | faya
# Processing Record 10 of Set 11 | ippy
# Processing Record 11 of Set 11 | dakoro
# Processing Record 12 of Set 11 | gurupi
# Processing Record 13 of Set 11 | jaciara
# Processing Record 14 of Set 11 | ilhabela
# Processing Record 15 of Set 11 | shache
# Processing Record 16 of Set 11 | gusau
# Processing Record 17 of Set 11 | napasar
# Processing Record 18 of Set 11 | azuqueca de henares
# Processing Record 19 of Set 11 | tourlaville
# Processing Record 20 of Set 11 | stockelsdorf
# Processing Record 21 of Set 11 | loandjili
# Processing Record 22 of Set 11 | montepuez
# Processing Record 23 of Set 11 | asosa
# Processing Record 24 of Set 11 | kostomuksha
# Processing Record 25 of Set 11 | zawadzkie
# Processing Record 26 of Set 11 | murgab
# Processing Record 27 of Set 11 | camacha
# Processing Record 28 of Set 11 | salinas
# Processing Record 29 of Set 11 | elbistan
# Processing Record 30 of Set 11 | port-cartier
# Processing Record 31 of Set 11 | gayeri
# Processing Record 32 of Set 11 | karera
# Processing Record 33 of Set 11 | nangomba
# Processing Record 34 of Set 11 | sarankhola
# Processing Record 35 of Set 11 | lincoln
# Processing Record 36 of Set 11 | pemba
# Processing Record 37 of Set 11 | kushmurun
# Processing Record 38 of Set 11 | louis trichardt
# Processing Record 39 of Set 11 | rio esteban
# Processing Record 40 of Set 11 | richards bay
# Processing Record 41 of Set 11 | zhob
# Processing Record 42 of Set 11 | birin
# Processing Record 43 of Set 11 | carnarvon
# Processing Record 44 of Set 11 | ubata
# Processing Record 45 of Set 11 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 46 of Set 11 | udimskiy
# Processing Record 47 of Set 11 | lugoba
# Processing Record 48 of Set 11 | baillif
# Processing Record 49 of Set 11 | isabela
# Processing Record 50 of Set 11 | beruwala
# Processing Record 1 of Set 12 | muros
# Processing Record 2 of Set 12 | birao
# Processing Record 3 of Set 12 | carupano
# Processing Record 4 of Set 12 | krasnoselkup
# Processing Record 5 of Set 12 | abdulino
# Processing Record 6 of Set 12 | beloomut
# Processing Record 7 of Set 12 | mizan teferi
# Processing Record 8 of Set 12 | mankono
# Processing Record 9 of Set 12 | bojnurd
# Processing Record 10 of Set 12 | hude
# Processing Record 11 of Set 12 | llata
# Processing Record 12 of Set 12 | visnes
# Processing Record 13 of Set 12 | durban
# Processing Record 14 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 12 | marathon
# Processing Record 16 of Set 12 | riviere-au-renard
# Processing Record 17 of Set 12 | duz
# City not found. Skipping...
# Processing Record 18 of Set 12 | altayskoye
# Processing Record 19 of Set 12 | bergama
# Processing Record 20 of Set 12 | rio cuarto
# Processing Record 21 of Set 12 | ipanema
# Processing Record 22 of Set 12 | malinovoye ozero
# Processing Record 23 of Set 12 | verkhnyaya inta
# Processing Record 24 of Set 12 | goure
# Processing Record 25 of Set 12 | koster
# Processing Record 26 of Set 12 | mabaruma
# Processing Record 27 of Set 12 | lyaskelya
# Processing Record 28 of Set 12 | miraflores
# Processing Record 29 of Set 12 | zhezkazgan
# Processing Record 30 of Set 12 | farah
# Processing Record 31 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 32 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 33 of Set 12 | oranjemund
# Processing Record 34 of Set 12 | mazyr
# Processing Record 35 of Set 12 | kalmunai
# Processing Record 36 of Set 12 | lodja
# Processing Record 37 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 12 | amantea
# Processing Record 39 of Set 12 | limon
# Processing Record 40 of Set 12 | arkadak
# Processing Record 41 of Set 12 | pompeia
# Processing Record 42 of Set 12 | skibbereen
# Processing Record 43 of Set 12 | woudenberg
# Processing Record 44 of Set 12 | suffolk
# Processing Record 45 of Set 12 | tessalit
# Processing Record 46 of Set 12 | agirish
# Processing Record 47 of Set 12 | san lawrenz
# Processing Record 48 of Set 12 | tikaitnagar
# Processing Record 49 of Set 12 | alvand
# Processing Record 50 of Set 12 | ekibastuz
# Processing Record 1 of Set 13 | lukovetskiy
# Processing Record 2 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 13 | ayagoz
# Processing Record 4 of Set 13 | kemijarvi
# Processing Record 5 of Set 13 | muyezerskiy
# Processing Record 6 of Set 13 | markala
# Processing Record 7 of Set 13 | nushki
# Processing Record 8 of Set 13 | acarau
# Processing Record 9 of Set 13 | wagar
# Processing Record 10 of Set 13 | manta
# Processing Record 11 of Set 13 | ermelo
# Processing Record 12 of Set 13 | abu samrah
# Processing Record 13 of Set 13 | sarkand
# Processing Record 14 of Set 13 | loum
# Processing Record 15 of Set 13 | encruzilhada
# Processing Record 16 of Set 13 | yangambi
# Processing Record 17 of Set 13 | goundam
# Processing Record 18 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 13 | harsud
# Processing Record 20 of Set 13 | butterworth
# Processing Record 21 of Set 13 | qarqin
# Processing Record 22 of Set 13 | tamara
# Processing Record 23 of Set 13 | artyom
# Processing Record 24 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 25 of Set 13 | ahtopol
# Processing Record 26 of Set 13 | mecca
# Processing Record 27 of Set 13 | sauda
# Processing Record 28 of Set 13 | moche
# Processing Record 29 of Set 13 | lekoni
# Processing Record 30 of Set 13 | harper
# Processing Record 31 of Set 13 | zapolyarnyy
# Processing Record 32 of Set 13 | nieuw amsterdam
# Processing Record 33 of Set 13 | japura
# Processing Record 34 of Set 13 | changji
# Processing Record 35 of Set 13 | balkhash
# Processing Record 36 of Set 13 | kharp
# Processing Record 37 of Set 13 | dondo
# Processing Record 38 of Set 13 | darab
# Processing Record 39 of Set 13 | jerez
# Processing Record 40 of Set 13 | iquique
# Processing Record 41 of Set 13 | marathopolis
# City not found. Skipping...
# Processing Record 42 of Set 13 | vila do maio
# Processing Record 43 of Set 13 | krasnokholm
# Processing Record 44 of Set 13 | rabo de peixe
# Processing Record 45 of Set 13 | voyvozh
# Processing Record 46 of Set 13 | prieska
# Processing Record 47 of Set 13 | bari sadri
# Processing Record 48 of Set 13 | mont-de-marsan
# Processing Record 49 of Set 13 | pangody
# Processing Record 50 of Set 13 | stykkisholmur
# Processing Record 1 of Set 14 | parrita
# Processing Record 2 of Set 14 | moengo
# Processing Record 3 of Set 14 | sokoni
# Processing Record 4 of Set 14 | mana
# Processing Record 5 of Set 14 | aswan
# Processing Record 6 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 14 | ashland
# Processing Record 8 of Set 14 | berbera
# Processing Record 9 of Set 14 | scarborough
# Processing Record 10 of Set 14 | mezhdurechensk
# Processing Record 11 of Set 14 | khorion
# City not found. Skipping...
# Processing Record 12 of Set 14 | brae
# Processing Record 13 of Set 14 | grand baie
# Processing Record 14 of Set 14 | puerto cabezas
# Processing Record 15 of Set 14 | lucea
# Processing Record 16 of Set 14 | nizhniy baskunchak
# Processing Record 17 of Set 14 | tosya
# Processing Record 18 of Set 14 | sarmanovo
# Processing Record 19 of Set 14 | labelle
# Processing Record 20 of Set 14 | saint-paul
# Processing Record 21 of Set 14 | nicoya
# Processing Record 22 of Set 14 | pimenta bueno
# Processing Record 23 of Set 14 | kathu
# Processing Record 24 of Set 14 | kalabo
# Processing Record 25 of Set 14 | esmeralda
# Processing Record 26 of Set 14 | gurupa
# Processing Record 27 of Set 14 | fos-sur-mer
# Processing Record 28 of Set 14 | vila franca do campo
# Processing Record 29 of Set 14 | felanitx
# Processing Record 30 of Set 14 | andenes
# Processing Record 31 of Set 14 | turbat
# Processing Record 32 of Set 14 | miandrivazo
# Processing Record 33 of Set 14 | burica
# City not found. Skipping...
# Processing Record 34 of Set 14 | inhambane
# Processing Record 35 of Set 14 | sikasso
# Processing Record 36 of Set 14 | mumford
# Processing Record 37 of Set 14 | kudahuvadhoo
# Processing Record 38 of Set 14 | seoni
# Processing Record 39 of Set 14 | westport
# Processing Record 40 of Set 14 | rocha
# Processing Record 41 of Set 14 | santo tomas
# Processing Record 42 of Set 14 | shu
# Processing Record 43 of Set 14 | kempele
# Processing Record 44 of Set 14 | namibe
# Processing Record 45 of Set 14 | bani walid
# Processing Record 46 of Set 14 | coruripe
# Processing Record 47 of Set 14 | banda aceh
# Processing Record 48 of Set 14 | trairi
# Processing Record 49 of Set 14 | paita
# Processing Record 50 of Set 14 | campechuela
# Processing Record 1 of Set 15 | mandera
# Processing Record 2 of Set 15 | syracuse
# Processing Record 3 of Set 15 | sambava
# Processing Record 4 of Set 15 | imeni zhelyabova
# Processing Record 5 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 15 | varniai
# Processing Record 7 of Set 15 | arroyo
# Processing Record 8 of Set 15 | ariguani
# Processing Record 9 of Set 15 | tabou
# Processing Record 10 of Set 15 | bagotville
# Processing Record 11 of Set 15 | aqtobe
# Processing Record 12 of Set 15 | sabla
# Processing Record 13 of Set 15 | cordoba
# Processing Record 14 of Set 15 | el pinon
# Processing Record 15 of Set 15 | quixeramobim
# Processing Record 16 of Set 15 | kutum
# Processing Record 17 of Set 15 | baracoa
# Processing Record 18 of Set 15 | prado
# Processing Record 19 of Set 15 | henties bay
# Processing Record 20 of Set 15 | konevo
# Processing Record 21 of Set 15 | khromtau
# Processing Record 22 of Set 15 | kaniama
# Processing Record 23 of Set 15 | sadove
# Processing Record 24 of Set 15 | ardesen
# Processing Record 25 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 26 of Set 15 | carutapera
# Processing Record 27 of Set 15 | shelburne
# Processing Record 28 of Set 15 | brazzaville
# Processing Record 29 of Set 15 | diamantino
# Processing Record 30 of Set 15 | ilam
# Processing Record 31 of Set 15 | san rafael
# Processing Record 32 of Set 15 | ust-tsilma
# Processing Record 33 of Set 15 | kasongo
# Processing Record 34 of Set 15 | ji-parana
# City not found. Skipping...
# Processing Record 35 of Set 15 | zastron
# Processing Record 36 of Set 15 | altamira
# Processing Record 37 of Set 15 | gamboula
# Processing Record 38 of Set 15 | dudinka
# Processing Record 39 of Set 15 | challapata
# Processing Record 40 of Set 15 | santa lucia
# Processing Record 41 of Set 15 | linhares
# Processing Record 42 of Set 15 | dakar
# Processing Record 43 of Set 15 | pyskowice
# Processing Record 44 of Set 15 | cross lanes
# Processing Record 45 of Set 15 | mulki
# Processing Record 46 of Set 15 | zeerust
# Processing Record 47 of Set 15 | aklera
# Processing Record 48 of Set 15 | dhidhdhoo
# Processing Record 49 of Set 15 | moba
# Processing Record 50 of Set 15 | rorvik
# Processing Record 1 of Set 16 | baijiantan
# Processing Record 2 of Set 16 | ust-shonosha
# Processing Record 3 of Set 16 | arrecife
# Processing Record 4 of Set 16 | gravdal
# Processing Record 5 of Set 16 | urucara
# Processing Record 6 of Set 16 | kerman
# Processing Record 7 of Set 16 | dangriga
# Processing Record 8 of Set 16 | fonte boa
# Processing Record 9 of Set 16 | macusani
# Processing Record 10 of Set 16 | gogrial
# Processing Record 11 of Set 16 | bogovarovo
# Processing Record 12 of Set 16 | isfana
# Processing Record 13 of Set 16 | edirne
# Processing Record 14 of Set 16 | sakakah
# Processing Record 15 of Set 16 | morant bay
# Processing Record 16 of Set 16 | san antonio
# Processing Record 17 of Set 16 | zabrat
# Processing Record 18 of Set 16 | gedo
# Processing Record 19 of Set 16 | chitradurga
# Processing Record 20 of Set 16 | banyo
# Processing Record 21 of Set 16 | point pedro
# Processing Record 22 of Set 16 | mayumba
# Processing Record 23 of Set 16 | whitehaven
# Processing Record 24 of Set 16 | tashtagol
# Processing Record 25 of Set 16 | louga
# Processing Record 26 of Set 16 | lardos
# Processing Record 27 of Set 16 | san juan
# Processing Record 28 of Set 16 | graaff-reinet
# Processing Record 29 of Set 16 | magdeburg
# Processing Record 30 of Set 16 | panguipulli
# Processing Record 31 of Set 16 | mbanza-ngungu
# Processing Record 32 of Set 16 | baran
# Processing Record 33 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 16 | manaure
# Processing Record 35 of Set 16 | viransehir
# Processing Record 36 of Set 16 | ponta delgada
# Processing Record 37 of Set 16 | el badari
# City not found. Skipping...
# Processing Record 38 of Set 16 | mallama
# City not found. Skipping...
# Processing Record 39 of Set 16 | great yarmouth
# Processing Record 40 of Set 16 | sabha
# Processing Record 41 of Set 16 | ostrovnoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Gondar      ET  12.6000  37.4667     57.92        90         100
# 1   Fereydun Kenar      IR  36.6864  52.5225     80.82        89           0
# 2         Olafsvik      IS  64.8945 -23.7142     51.24        83          84
# 3        Sinnamary      GF   5.3833 -52.9500     81.97        72          69
# 4         Cururupu      BR  -1.8283 -44.8683     85.69        60          42
# 5              Eyl      SO   7.9803  49.8164     78.06        73           6
# 6       Sankeshwar      IN  16.2667  74.4833     71.31        93         100
# 7  Arraial Do Cabo      BR -22.9661 -42.0278     78.66        69           0
# 8           Banepa      NP  27.6298  85.5214     73.72        83          75
# 9    Saint Anthony      US  45.0205 -93.2180     89.94        51          40
#
#    Wind Speed Current Description
# 0        3.36          light rain
# 1        0.00           clear sky
# 2        5.01       broken clouds
# 3        4.03       broken clouds
# 4        5.95    scattered clouds
# 5       31.72           clear sky
# 6       10.83     overcast clouds
# 7       10.36           clear sky
# 8        4.61       broken clouds
# 9        9.22    scattered clouds

# %%
#Create the output file (CSV)
output_file = "WeatherPy_Database.csv"
#Export data to file
city_data_df.to_csv(output_file, index_label="City ID")
